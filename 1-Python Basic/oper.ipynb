# %%
# Arithmetic Operators
a = 10
b = 3
add_result = a + b
sub_result = a - b
mul_result = a * b
div_result = a / b
mod_result = a % b
floor_result = a//b
expo_result = a**b
print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
print(mod_result)
print(floor_result)
print(expo_result)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 3
# 1000

# %%
a=10
b =10
print(a==b)
# Out:
# True

# %%
str1 = "krish"
str2 = "krish"
str1==str2
# Out:
# True

# %%
str1!=str2
# Out:
# False

# %%
str3="Krish"
str4 = "krish"
str3!=str4
# Out:
# True

# %%
num1 = 45
num2 = 55
num1>num2
# Out:
# False

# %%
##logical operators
x = True
y = True

result = x and y
print(result)
# Out:
# True

# %%
result2 = x or y
print(result2)
# Out:
# True

# %%
z = False
result3 = x and z
print(result3)
# Out:
# False

# %%
result4 = x or z
print(result4)
# Out:
# True

# %%
not z
# Out:
# True

# %%
num1 = float(input("Enter the first number:"))
num2 = float(input("Enter the sencond number:"))


addition = num1 + num2
substraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
modulus = num1 % num2
exponential = num1 ** num2


print("The addition of 2 number is :", addition)
print("The substraction of the 2 numbers is :" , substraction)
print("The multiplication of the 2 numbers is:",multiplication)
print("The division of the 2 numbers is:",division)
print("The modulus of the 2 numbers is:",modulus)
print("The exponential of the 2 numbers is:",exponential)
# Out:
# The addition of 2 number is : 57.0
# The substraction of the 2 numbers is : -11.0
# The multiplication of the 2 numbers is: 782.0
# The division of the 2 numbers is: 0.6764705882352942
# The modulus of the 2 numbers is: 23.0
# The exponential of the 2 numbers is: 1.9895113660064588e+46
