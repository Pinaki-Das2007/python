# %%
# Arithmetic Operators
a = 10
b = 3
add_result = a + b
sub_result = a - b
mul_result = a * b
div_result = a / b
mod_result = a % b
floor_result = a//b
expo_result = a**b
print(add_result)
print(sub_result)
print(mul_result)
print(div_result)
print(mod_result)
print(floor_result)
print(expo_result)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 1
# 3
# 1000
