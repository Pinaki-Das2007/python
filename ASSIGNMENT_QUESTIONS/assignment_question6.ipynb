# %% [markdown]
# Module 3. Data Structures Assignements

# %% [markdown]
# Lesson 3.4: Dictionaries

# %% [markdown]
# 3.4.1

# %%
d = {i : i **2 for i in range(1,11)}
print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %% [markdown]
# 3.4.2

# %%
print(f"Value of key 5: {d[5]}")
print(f"Keys: {list(d.keys())}")

# %% [markdown]
# 3.4.3

# %%
d[11] = 121
d.pop(1)
print(d)

# %% [markdown]
# 3.4.4

# %%
for key, value in d.tems():
    print(f"{key}: {value}")

# %% [markdown]
# 3.4.5

# %%
cubes = {i:i**3 for i in range(1,11)}
print(cubes)

# %% [markdown]
# 3.4.6

# %%
d1 = {i:i**2 for i in range(1,6)}
d2 = {i:i**2 for i in range(6,11)}
d1.update(d2)
print(d1)

# %% [markdown]
# 3.4.7

# %%
student = {
    'name': 'John snow targerian',
    'age': 24,
    'grades':{
        'math':90,
        'science':80,
        'english':70
    }
}
print(student)

# %% [markdown]
# 3.4.8

# %%
multiple = {i:[i*i for j in range(1,6)] for i in range(1,6)}
print(multiple)

# %% [markdown]
# 3.4.9

# %%
tuple_dict = {i: (i, i**2) for i in range(1, 6)}
print(tuple_dict)

# %% [markdown]
# 3.4.10

# %%
d = {i:i**2 for i in range(1,11)}
list_of_dict = list(d.items())
print(list_of_dict)

# %% [markdown]
# 3.4.11

# %%
d = {i:i**2 for i in range(1,11)}
even_dict = {k: v for k, v in d.items() if k % 2 == 0}
print(even_dict)

# %% [markdown]
# 3.4.12

# %%
d = {i:i**2 for i in range(1,6)}
swapped_dict = {v: k for k , v in d.items()}
print(swapped_dict)

# %% [markdown]
# 3.4.13

# %%
from collections import defaultdict

default_dict = defaultdict(list)
default_dict['a'.append(1)]
default_dict['b'.appened(2)]
default_dict['c'.appened(3)]
print(default_dict)

# %% [markdown]
# 3.4.14

# %%
def count_chars(s):
    count_dict = {}
    for char in s:
        count_dict[char] = count_dict.get(char,0)+1
    return count_dict

string = "Hello world"
print(count_chars(string))

# %% [markdown]
# 3.4.15

# %%
import json

book = {
    'title': 'Game of thrones',
    'author': 'George R. R. Martin',
    'year': 1996,
    'genre': 'Fantasy'
}

book_json = json.dumps(book)
print(book_json)
