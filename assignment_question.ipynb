# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello World")

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
str1= str(input("Eneter your name:"))
print("Hello",str1,"welcome to my answer sheet")

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
num1 = int(input("Enter first number:"))
if num1>0:
    print("The number is positive")
elif num1<0:
    print("The number is negative")
else:
    print("The number is Zero")
# Out:
# The number is positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
a = 23
b = 45
c =10

if a>b and a>c:
    print("a is the greatest")

elif b>a and b>c:
    print("b is the greatest")

else:
    print("c is the greatest")
# Out:
# b is the greatest

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
    
n = int(input("Enter the number to find its factorial:"))

factorial_result = factorial(n)

print("The factorial of ", n , "is:", factorial_result)
# Out:
# The factorial of  5 is: 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
a = 12
b = 23.34
c = "Pinaki"
d = True

print(a)
print(type(a))

print(b)
print(type(b))

print(c)
print(type(c))

print(d)
print(type(d))
# Out:
# 12
# <class 'int'>
# 23.34
# <class 'float'>
# Pinaki
# <class 'str'>
# True
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
a = int(input("Enter the first number:"))
b = int(input("Enter the second number:"))
c 


c= a
a = b
b = c

print("After swapping:")
print("a =", a)
print("b =", b)

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
c = float(input("Enter the temperature in Celcius:"))
f= (c *9/5) + 32
print("The temperature in Frenheit is :",f)

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
str1 = "Hello"
str2 = "world"

Conc_str = str1 + " "+ str2
print("The string after concatination is:", Conc_str)
# Out:
# The string after concatination is: Hello world

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
var = 10.5
if isinstance(var, float):
    print(f"{var} is a float")
else:
    print(f"{var} is not a float")

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
num1 = int(input("Enter the first number:"))
num2 = int(input("Enter the second number:"))

addition = num1 + num2
print ("The addition operator is :" , addition)

substraction = num1 - num2
print("The substraction operator is :",substraction)

multiplication = num1 * num2
print ("The multiplication operator is :", multiplication)

division = num1 / num2
print("The division operator is : ", division)
# Out:
# The addition operator is : 57
# The substraction operator is : -11
# The multiplication operator is : 782
# The division operator is :  0.6764705882352942

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
num3 = int(input("Enter the first number to check :"))
num4 = int(input("Enter the second number to check :"))

if num3 == num4:
    print("The numbers are equal")

if num3 != num4:
    print("The numbers are not equal")

if num3 > num4:
    print("The first number is greater than the second number")

if num3 < num4:
    print("The first number is less than the second number")
# Out:
# The numbers are not equal
# The first number is less than the second number

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
n1 = True
n2= True
n3 = False
n4 = False

print("AND")
print("The logical expression is:", n1 and n2 )
print("The logical expression is:", n3 and n4 )
print("The logical expression is:", n1 and n3 )
print("The logical expression is:", n2 and n4 )


print("OR")
print("The logical expression is:", n1 or n2 )
print("The logical expression is:", n3 or n4 )
print("The logical expression is:", n1 or n3 )
print("The logical expression is:", n2 or n4 )


print("NOT")
print("The logical expression is:", not n1)
print("The logical expression is:", not n3)
# Out:
# AND
# The logical expression is: True
# The logical expression is: False
# The logical expression is: False
# The logical expression is: False
# OR
# The logical expression is: True
# The logical expression is: False
# The logical expression is: True
# The logical expression is: True
# NOT
# The logical expression is: False
# The logical expression is: True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
num = int(input("Enter the number for which you want to find the square :"))

square = num * num  
print("The square of" , num ,"is" , square)

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
num = int(input("Enter the number to check if it is odd or even:"))
if num % 2 == 0:
    print("The number is even")
else:
    print("The number is odd")

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
n = int(input("Enter the range of numbers to print the sum of the natural numbers:"))
sum = 0
for i in range(1 ,n+1):
    sum = sum + i
print("The sum of the natural numbers is :", sum)
# Out:
# The sum of the natural numbers is : 15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Solution
string = input("Enter a string: ")
reversed_string = string[::-1]
print(f"The reversed string is: {reversed_string}")

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
string = input("Enter a string: ")
if string == string[::-1]:
    print(f"{string} is a palindrome.")
else:
    print(f"{string} is not a palindrome.")

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
numbers = [int(x) for x in input("Enter numbers separated by space: ").split()]
numbers.sort()
print(f"Sorted list: {numbers}")
