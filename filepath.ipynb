# %%
## create a new directory
import os
new_directory = "package"
print(f"Directory '{new_directory}' created.")
# Out:
# Directory 'package' created.

# %%
## Listing Files and Directories

items = os.listdir()
print("Items in the current directory:")
for item in items:
    print(item)
# Out:
# Items in the current directory:
# .git
# .gitignore
# .ipynb_checkpoints
# .vscode
# 1-Python Basic
# advancefunctionsolution.ipynb
# app.py
# ASSIGNMENT_QUESTIONS
# creatingvenv.md
# destination.txt
# dictinoary.ipynb
# dictionaries_assignment.ipynb
# dictonary.py
# example.bin
# example.csv
# example.txt
# example_function.ipynb
# fileoperations.ipynb
# filepath.ipynb
# filter_functions.ipynb
# function.ipynb
# import_modules.ipynb
# lambdafunction.ipynb
# listing.py
# listslicing.py
# list_Assignment.ipynb
# list_assignment_solution.ipynb
# map_functions.ipynb
# module.py
# package
# packagesquestion.ipynb
# packng&unpacking.py
# proxy.txt
# readme.md
# realworlduse.ipynb
# requirements.txt
# sample.txt
# sets.py
# source.txt
# standardlib.ipynb
# strinng_met.py
# test.py
# test_dir
# tuples.py
# tuple_assignment_solution.ipynb
# tupple.ipynb
# updated.txt
# venv

# %%
## Listing Files And Directories with Details
items=os.listdir('.')
print(items)
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', '.vscode', '1-Python Basic', 'advancefunctionsolution.ipynb', 'app.py', 'ASSIGNMENT_QUESTIONS', 'creatingvenv.md', 'destination.txt', 'dictinoary.ipynb', 'dictionaries_assignment.ipynb', 'dictonary.py', 'example.bin', 'example.csv', 'example.txt', 'example_function.ipynb', 'fileoperations.ipynb', 'filepath.ipynb', 'filter_functions.ipynb', 'function.ipynb', 'import_modules.ipynb', 'lambdafunction.ipynb', 'listing.py', 'listslicing.py', 'list_Assignment.ipynb', 'list_assignment_solution.ipynb', 'map_functions.ipynb', 'module.py', 'package', 'packagesquestion.ipynb', 'packng&unpacking.py', 'proxy.txt', 'readme.md', 'realworlduse.ipynb', 'requirements.txt', 'sample.txt', 'sets.py', 'source.txt', 'standardlib.ipynb', 'strinng_met.py', 'test.py', 'test_dir', 'tuples.py', 'tuple_assignment_solution.ipynb', 'tupple.ipynb', 'updated.txt', 'venv']

# %%
#### Joining Paths
import os
dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join(os.getcwd(),dir_name, file_name)
print(full_path)
# Out:
# c:\Users\PINAKI\Python\folder\file.txt

# %%
path = "example1.txt"
if os.path.exists(path):
    print(f"The file'{path}' exists. ")
else:
    print(f"The file '{path}' does not exists.")
# Out:
# The file 'example1.txt' does not exists.

# %%
#Checking if a Path is a file or a directory
import os

path = "example.txt"
if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else :
    print(f"The path '{path}' does not exist.")
# Out:
# The path 'example.txt' is a file.

# %%
## Getting the absolute Path 
relative_path = 'example.txt'
aboslute_path = os.path.abspath(relative_path)
print(aboslute_path)
# Out:
# c:\Users\PINAKI\Python\example.txt
