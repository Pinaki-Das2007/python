# %% [markdown]
# ## Data Visualization using Matplotlib
#
# Matplotlib is a powerful library for Pyton thzt enables the creation of static, animated, and interactive visualizations. It is widely used for data visualization in data science and analytics. In this lesson, we will cover the basic of Matplotlib, including creating various types of plots and customizing them.

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [1,4,9,16,25]

# create a line plot
plt.plot(x,y)
plt.xlabel('X-axis')
plt.ylabel('y-axis')
plt.title("Basic line plot")
plt.show()

# %%
x =  [1,2,3,4,5]
y = [1,4,9,16,25]

# create a customized line plot

plt.plot(x,y,color = 'red',linestyle = "--")
