# %% [markdown]
# # Pandas- DataFrame And Series
#
# Pandas is a powerful data manipulation library in Python, widely used for data cleaning. It provides two primary data structures. DataFrame and structures: Series and dataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional,size-mutable, and potentially hetrogeneous tabular data structure with labeled axes (rows and columns).

# %%
import pandas as pd

# %%
## Series
## Pandas Series is a one-dimensional array-like onject that can hold any data type. It is similar to a column in a table.

import pandas as pd
data=[1,2,3,4,5]
series = pd.Series(data)
print(series)
print(type(series))
print("Series \n",series)

# %%
# Create a series from dictionary
data={"a":1,"b":2,"c":3}
series_dict =pd.Series(data) 
print(series_dict)

# %%
data = [10,20,30]
index = ["a","b","c"]
pd.Series(data,index=index)

# %%
## Dataframe
## Create a DataFrame from a dictionary of lists

data = {
    "Name":['Krish','John','Harry'],
    "Age":[25,30,45],
    "city":['Banglore','New York','Florida']
}

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age      city
# 0  Krish   25  Banglore
# 1   John   30  New York
# 2  Harry   45   Florida
# <class 'pandas.DataFrame'>

# %%
## Create a DataFrame from a list of Dictionaries

data = [
    {"Name":"Krish","Age":25,"City":"Banglore"},
    {"Name":"John","Age":32,"City":"Banglore"},
    {"Name":"Bappy","Age":25,"City":"Banglore"},
    {"Name":"Jack","Age":25,"City":"Banglore"}
]

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age      City
# 0  Krish   25  Banglore
# 1   John   32  Banglore
# 2  Bappy   25  Banglore
# 3   Jack   25  Banglore
# <class 'pandas.DataFrame'>

# %%
df = pd.read_csv("sales_data.csv")
df.head(5)
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
# Display the data types of each column
print("Data types:\n",df.dtypes)

# Describe the Dataframe
print("Describe:\n",df.describe())

# Group by a column and perform an aggregation 
grouped = df.groupby("Product Category")["Total Revenue"].mean()
print("Mean value by category:\n",grouped)
# Out:
# Data types:
#  Transaction ID        int64
# Date                    str
# Product Category        str
# Product Name            str
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region                  str
# Payment Method          str
# dtype: object
# Describe:
#         Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000
# Mean value by category:
#  Product Category
# Beauty Products     65.54750
# Books               46.54825
# Clothing           203.22325
# Electronics        874.56025
# Home Appliances    466.15400
# Sports             358.16300
# Name: Total Revenue, dtype: float64

# %%
df.describe()
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000

# %%
df.tail(5)

# %%
# Accessing a specified element

df.at[2,"Name"]
# Out:
# 'Harry'

# %%
## Acdessing a specified element using iat
df.iat[2,2]
# Out:
# 'Florida'

# %%
### Data manipulation with dataframes

df
# Out:
#     Name  Age      city
# 0  Krish   25  Banglore
# 1   John   30  New York
# 2  Harry   45   Florida

# %%
# Adding a column
df["Salary"]=[50000,60000,70000]
df
# Out:
#     Name  Age      city  Salary
# 0  Krish    2  Banglore   50000
# 1   John    2  New York   60000
# 2  Harry    2   Florida   70000

# %%
## Remove a column

df.drop("Salary",axis=1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 3
#       1 ## Remove a column
#       2
# ----> 3 df.drop("Salary",axis=1,inplace = True)
#
# File c:\Users\PINAKI\Python\venv\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File c:\Users\PINAKI\Python\venv\Lib\site-packages\pandas\core\generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
#    4631             if labels is not None:
# -> 4632                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4633
#    4634         if inplace:
#    4635             self._update_inplace(obj)
#
# File c:\Users\PINAKI\Python\venv\Lib\site-packages\pandas\core\generic.py:4674, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4670                 if not isinstance(axis, MultiIndex):
#    4671                     raise AssertionError("axis must be a MultiIndex")
#    4672                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4673             else:
# -> 4674                 new_axis = axis.drop(labels, errors=errors)
#    4675             indexer = axis.get_indexer(new_axis)
#    4676
#    4677         # Case for non-unique axis
#
# File c:\Users\PINAKI\Python\venv\Lib\site-packages\pandas\core\indexes\base.py:7268, in Index.drop(self, labels, errors)
#    7266 if mask.any():
#    7267     if errors != "ignore":
# -> 7268         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7269     indexer = indexer[~mask]
#    7270 return self.delete(indexer)
#
# KeyError: "['Salary'] not found in axis"

# %%
df
# Out:
#     Name  Age      city
# 0  Krish    2  Banglore
# 1   John    2  New York
# 2  Harry    2   Florida

# %%
## Add age to the column after a year

df["Age"]= df["Age"]+1
df
# Out:
#     Name  Age      city
# 0  Krish    2  Banglore
# 1   John    2  New York
# 2  Harry    2   Florida
