# %%
mixed_tuple = (1, "hello", 3.14, [1, 2, 3], (4, 5))
mixed_tuple * 3
# Out:
# (1,
#  'hello',
#  3.14,
#  [1, 2, 3],
#  (4, 5),
#  1,
#  'hello',
#  3.14,
#  [1, 2, 3],
#  (4, 5),
#  1,
#  'hello',
#  3.14,
#  [1, 2, 3],
#  (4, 5))
